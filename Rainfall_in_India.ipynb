# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"C:\Users\bannu\Desktop\cards\Tefologic Training\rainfall in india 1901-2015.csv")

# %%
data.head(5)
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
data.shape
# Out:
# (4116, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4112 non-null   float64
#  3   FEB          4113 non-null   float64
#  4   MAR          4110 non-null   float64
#  5   APR          4112 non-null   float64
#  6   MAY          4113 non-null   float64
#  7   JUN          4111 non-null   float64
#  8   JUL          4109 non-null   float64
#  9   AUG          4112 non-null   float64
#  10  SEP          4110 non-null   float64
#  11  OCT          4109 non-null   float64
#  12  NOV          4105 non-null   float64
#  13  DEC          4106 non-null   float64
#  14  ANNUAL       4090 non-null   float64
#  15  Jan-Feb      4110 non-null   float64
#  16  Mar-May      4107 non-null   float64
#  17  Jun-Sep      4106 non-null   float64
# ...

# %%
data.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
data.isnull().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb', 'Mar-May',
#        'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
data.groupby('SUBDIVISION').count()
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...

# %%
df=data.drop(['ANNUAL', 'Jan-Feb', 'Mar-May',
       'Jun-Sep', 'Oct-Dec'],axis=1)

# %%
df.head(5)
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC
# 0  365.1  481.1  332.6  388.5  558.2   33.6
# 1  228.9  753.7  666.2  197.2  359.0  160.5
# 2  728.4  326.7  339.0  181.2  284.4  225.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1
# 4  368.7  330.5  297.0  260.7   25.4  344.7

# %%
df.hist(figsize=(12,12))
# Out:
# array([[<AxesSubplot:title={'center':'YEAR'}>,
#         <AxesSubplot:title={'center':'JAN'}>,
#         <AxesSubplot:title={'center':'FEB'}>,
#         <AxesSubplot:title={'center':'MAR'}>],
#        [<AxesSubplot:title={'center':'APR'}>,
#         <AxesSubplot:title={'center':'MAY'}>,
#         <AxesSubplot:title={'center':'JUN'}>,
#         <AxesSubplot:title={'center':'JUL'}>],
#        [<AxesSubplot:title={'center':'AUG'}>,
#         <AxesSubplot:title={'center':'SEP'}>,
#         <AxesSubplot:title={'center':'OCT'}>,
#         <AxesSubplot:title={'center':'NOV'}>],
#        [<AxesSubplot:title={'center':'DEC'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df['SUBDIVISION'].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
data1=df.loc[(df['SUBDIVISION']=='ANDAMAN & NICOBAR ISLANDS')]

# %%
data1.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC
# 0  365.1  481.1  332.6  388.5  558.2   33.6
# 1  228.9  753.7  666.2  197.2  359.0  160.5
# 2  728.4  326.7  339.0  181.2  284.4  225.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1
# 4  368.7  330.5  297.0  260.7   25.4  344.7

# %%
data1.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            2
# APR            2
# MAY            1
# JUN            2
# JUL            2
# AUG            2
# SEP            3
# OCT            2
# NOV            2
# DEC            3
# dtype: int64

# %%
data1['MAR'].fillna(data1['MAR'].mean(),inplace=True)
data1['APR'].fillna(data1['APR'].mean(),inplace=True)
data1['MAY'].fillna(data1['MAY'].mean(),inplace=True)
data1['JUN'].fillna(data1['JUN'].mean(),inplace=True)
data1['JUL'].fillna(data1['JUL'].mean(),inplace=True)
data1['AUG'].fillna(data1['AUG'].mean(),inplace=True)
data1['SEP'].fillna(data1['SEP'].mean(),inplace=True)
data1['OCT'].fillna(data1['OCT'].mean(),inplace=True)
data1['DEC'].fillna(data1['DEC'].mean(),inplace=True)
data1['NOV'].fillna(data1['NOV'].mean(),inplace=True)

# %%
data1.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data2=df.loc[(df['SUBDIVISION']=='ARUNACHAL PRADESH')]

# %%
data2.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            1
# FEB            1
# MAR            2
# APR            0
# MAY            0
# JUN            1
# JUL            1
# AUG            0
# SEP            0
# OCT            2
# NOV            2
# DEC            2
# dtype: int64

# %%
data2['JAN'].fillna(data2['JAN'].mean(),inplace=True)
data2['FEB'].fillna(data2['FEB'].mean(),inplace=True)
data2['MAR'].fillna(data2['MAR'].mean(),inplace=True)
data2['APR'].fillna(data2['APR'].mean(),inplace=True)
data2['MAY'].fillna(data2['MAY'].mean(),inplace=True)
data2['JUN'].fillna(data2['JUN'].mean(),inplace=True)
data2['JUL'].fillna(data2['JUL'].mean(),inplace=True)
data2['AUG'].fillna(data2['AUG'].mean(),inplace=True)
data2['SEP'].fillna(data2['SEP'].mean(),inplace=True)
data2['OCT'].fillna(data2['OCT'].mean(),inplace=True)
data2['DEC'].fillna(data2['DEC'].mean(),inplace=True)
data2['NOV'].fillna(data2['NOV'].mean(),inplace=True)

# %%
data2.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data3=df.loc[(df['SUBDIVISION']=='LAKSHADWEEP')]

# %%
data3.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            2
# FEB            1
# MAR            2
# APR            2
# MAY            2
# JUN            2
# JUL            3
# AUG            2
# SEP            3
# OCT            3
# NOV            6
# DEC            4
# dtype: int64

# %%
data3['JAN'].fillna(data3['JAN'].mean(),inplace=True)
data3['FEB'].fillna(data3['FEB'].mean(),inplace=True)
data3['MAR'].fillna(data3['MAR'].mean(),inplace=True)
data3['APR'].fillna(data3['APR'].mean(),inplace=True)
data3['MAY'].fillna(data3['MAY'].mean(),inplace=True)
data3['JUN'].fillna(data3['JUN'].mean(),inplace=True)
data3['JUL'].fillna(data3['JUL'].mean(),inplace=True)
data3['AUG'].fillna(data3['AUG'].mean(),inplace=True)
data3['SEP'].fillna(data3['SEP'].mean(),inplace=True)
data3['OCT'].fillna(data3['OCT'].mean(),inplace=True)
data3['DEC'].fillna(data3['DEC'].mean(),inplace=True)
data3['NOV'].fillna(data3['NOV'].mean(),inplace=True)

# %%
data3.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data4=df.loc[(df['SUBDIVISION']=='WEST MADHYA PRADESH')]

# %%
data4.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            1
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data4['FEB'].fillna(data4['FEB'].mean(),inplace=True)

# %%
data4.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data5=df.loc[(df['SUBDIVISION']=='COASTAL KARNATAKA')]

# %%
data5.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            1
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data5['JAN'].fillna(data5['JAN'].mean(),inplace=True)

# %%
data5.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data6=df.loc[(df['SUBDIVISION']=='JAMMU & KASHMIR')]

# %%
data6.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            1
# AUG            0
# SEP            0
# OCT            0
# NOV            1
# DEC            1
# dtype: int64

# %%
data6['JUL'].fillna(data6['JUL'].mean(),inplace=True)
data6['NOV'].fillna(data6['NOV'].mean(),inplace=True)
data6['DEC'].fillna(data6['DEC'].mean(),inplace=True)

# %%
data6.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
print(49.2+87.1+29.2+2.3+528.8+517.5+365.1+481.1+332.6+388.5+558.2+33.6)
# Out:
# 3373.1999999999994

# %%
#data2=data.drop(['ANNUAL', 'Jan-Feb', 'Mar-May',
       #'Jun-Sep', 'Oct-Dec'],axis=1)

# %%
#data2

# %%
data7=df.loc[(df['SUBDIVISION']=='KERALA')]
data7
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 3887      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 3888      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 3889      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3890      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 3891      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
# ...          ...   ...   ...   ...   ...    ...    ...     ...     ...    ...
# 3997      KERALA  2011  20.5  45.7  24.1  165.2  124.2   788.5   536.8  492.7
# 3998      KERALA  2012   7.4  11.0  21.0  171.1   95.3   430.3   362.6  501.6
# 3999      KERALA  2013   3.9  40.1  49.9   49.3  119.3  1042.7   830.2  369.7
# 4000      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8  733.9
# 4001      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0  252.2
#
#         SEP    OCT    NOV    DEC
# ...

# %%
data7['annual_1']=data[['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']].sum(axis=1)

# %%
data7.head(5)
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 3887      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 3888      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 3889      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3890      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 3891      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
#
#         SEP    OCT    NOV    DEC  annual_1
# 3887  197.7  266.9  350.8   48.4    3248.6
# 3888  491.6  358.4  158.3  121.5    3326.5
# 3889  341.8  354.1  157.0   59.0    3271.4
# 3890  222.7  328.1   33.9    3.3    3129.6
# 3891  217.2  383.5   74.4    0.2    2741.7

# %%
data8=df.loc[(df['SUBDIVISION']=='KERALA')]

# %%
data8['annual_2']=df[['JUN','JUL','AUG','SEP']].sum(axis=1)

# %%
data8.head(5)
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 3887      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 3888      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 3889      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3890      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 3891      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
#
#         SEP    OCT    NOV    DEC  annual_2
# 3887  197.7  266.9  350.8   48.4    2122.8
# 3888  491.6  358.4  158.3  121.5    2403.3
# 3889  341.8  354.1  157.0   59.0    2343.1
# 3890  222.7  328.1   33.9    3.3    2398.2
# 3891  217.2  383.5   74.4    0.2    1881.5

# %%
data_new=pd.concat([data1,data2,data3,data4,data5,data6],ignore_index=True)

# %%
data_new
# Out:
#                    SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY  \
# 0    ANDAMAN & NICOBAR ISLANDS  1901   49.2   87.1   29.2    2.3  528.8
# 1    ANDAMAN & NICOBAR ISLANDS  1902    0.0  159.8   12.2    0.0  446.1
# 2    ANDAMAN & NICOBAR ISLANDS  1903   12.7  144.0    0.0    1.0  235.1
# 3    ANDAMAN & NICOBAR ISLANDS  1904    9.4   14.7    0.0  202.4  304.5
# 4    ANDAMAN & NICOBAR ISLANDS  1905    1.3    0.0    3.3   26.9  279.5
# ..                         ...   ...    ...    ...    ...    ...    ...
# 661            JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4
# 662            JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9
# 663            JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4
# 664            JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7
# 665            JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6
#
#        JUN    JUL    AUG    SEP    OCT    NOV    DEC
# ...

# %%
df=df.loc[(df['SUBDIVISION']!='COASTAL KARNATAKA')]
df=df.loc[(df['SUBDIVISION']!='WEST MADHYA PRADESH')]
df=df.loc[(df['SUBDIVISION']!='ARUNACHAL PRADESH')]
df=df.loc[(df['SUBDIVISION']!='ANDAMAN & NICOBAR ISLANDS')]
df=df.loc[(df['SUBDIVISION']!='LAKSHADWEEP')]
df=df.loc[(df['SUBDIVISION']!='JAMMU & KASHMIR')]

# %%
df['SUBDIVISION'].unique()
# Out:
# array(['ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'WEST RAJASTHAN', 'EAST RAJASTHAN',
#        'EAST MADHYA PRADESH', 'GUJARAT REGION', 'SAURASHTRA & KUTCH',
#        'KONKAN & GOA', 'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA',
#        'CHHATTISGARH', 'COASTAL ANDHRA PRADESH', 'TELANGANA',
#        'RAYALSEEMA', 'TAMIL NADU', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA'], dtype=object)

# %%
final_data=pd.concat([data_new,df],ignore_index=True)

# %%
final_data
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5
# ...                         ...   ...   ...    ...   ...    ...    ...
# 4111                     KERALA  2011  20.5   45.7  24.1  165.2  124.2
# 4112                     KERALA  2012   7.4   11.0  21.0  171.1   95.3
# 4113                     KERALA  2013   3.9   40.1  49.9   49.3  119.3
# 4114                     KERALA  2014   4.6   10.3  17.9   95.7  251.0
# 4115                     KERALA  2015   3.1    5.8  50.1  214.1  201.8
#
#          JUN    JUL    AUG    SEP    OCT    NOV    DEC
# 0      517.5  365.1  481.1  332.6  388.5  558.2   33.6
# ...

# %%
final_data['ANNUAL']=final_data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
       'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].sum(axis=1)

# %%
data.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb', 'Mar-May',
#        'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
data['SUBDIVISION'].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
#mapping:
data_dict={'ANDAMAN & NICOBAR ISLANDS':0, 'ARUNACHAL PRADESH':1,
       'ASSAM & MEGHALAYA':2, 'NAGA MANI MIZO TRIPURA':3,
       'SUB HIMALAYAN WEST BENGAL & SIKKIM':4, 'GANGETIC WEST BENGAL':5,
       'ORISSA':6, 'JHARKHAND':7, 'BIHAR':8, 'EAST UTTAR PRADESH':9,
       'WEST UTTAR PRADESH':10, 'UTTARAKHAND':11, 'HARYANA DELHI & CHANDIGARH':12,
       'PUNJAB':13, 'HIMACHAL PRADESH':14, 'JAMMU & KASHMIR':15, 'WEST RAJASTHAN':16,
       'EAST RAJASTHAN':17, 'WEST MADHYA PRADESH':18, 'EAST MADHYA PRADESH':19,
       'GUJARAT REGION':20, 'SAURASHTRA & KUTCH':21, 'KONKAN & GOA':22,
       'MADHYA MAHARASHTRA':23, 'MATATHWADA':24, 'VIDARBHA':25, 'CHHATTISGARH':26,
       'COASTAL ANDHRA PRADESH':27, 'TELANGANA':28, 'RAYALSEEMA':29, 'TAMIL NADU':30,
       'COASTAL KARNATAKA':31, 'NORTH INTERIOR KARNATAKA':32,
       'SOUTH INTERIOR KARNATAKA':33, 'KERALA':34, 'LAKSHADWEEP':35}

# %%
final_data['SUBDIVISION']=final_data['SUBDIVISION'].map(data_dict)

# %%
x=final_data.drop(['ANNUAL'],axis=True)

# %%
x.head()
# Out:
#    SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN    JUL    AUG  \
# 0            0  1901  49.2   87.1  29.2    2.3  528.8  517.5  365.1  481.1
# 1            0  1902   0.0  159.8  12.2    0.0  446.1  537.1  228.9  753.7
# 2            0  1903  12.7  144.0   0.0    1.0  235.1  479.9  728.4  326.7
# 3            0  1904   9.4   14.7   0.0  202.4  304.5  495.1  502.0  160.1
# 4            0  1905   1.3    0.0   3.3   26.9  279.5  628.7  368.7  330.5
#
#      SEP    OCT    NOV    DEC
# 0  332.6  388.5  558.2   33.6
# 1  666.2  197.2  359.0  160.5
# 2  339.0  181.2  284.4  225.0
# 3  820.4  222.2  308.7   40.1
# 4  297.0  260.7   25.4  344.7

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   int64
#  1   YEAR         4116 non-null   int64
#  2   JAN          4116 non-null   float64
#  3   FEB          4116 non-null   float64
#  4   MAR          4116 non-null   float64
#  5   APR          4116 non-null   float64
#  6   MAY          4116 non-null   float64
#  7   JUN          4116 non-null   float64
#  8   JUL          4116 non-null   float64
#  9   AUG          4116 non-null   float64
#  10  SEP          4116 non-null   float64
#  11  OCT          4116 non-null   float64
#  12  NOV          4116 non-null   float64
#  13  DEC          4116 non-null   float64
# dtypes: float64(12), int64(2)
# memory usage: 450.3 KB

# %%
x.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
y=final_data['ANNUAL']

# %%
y.head()
# Out:
# 0    3373.2
# 1    3520.7
# 2    2957.4
# 3    3079.6
# 4    2566.7
# Name: ANNUAL, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=45)

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
r=LinearRegression()
r.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=r.predict(x_test)

# %%
y_pred
# Out:
# array([1163.4,  482.3,  424.8, ...,  907.9, 2705.6,  622. ])

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y_test)
# Out:
# 2.588292218193301e-25

# %%
Results= pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=y_pred
#Results['km']=X_test['km']
Results=Results.reset_index()
Results['Id']=Results.index
Results.head(10)
# Out:
#    index       Actual    Predicted  Id
# 0    246  1163.400000  1163.400000   0
# 1   2724   482.300000   482.300000   1
# 2   2033   424.800000   424.800000   2
# 3   2693   390.300000   390.300000   3
# 4    221  1545.500000  1545.500000   4
# 5     30  2941.606732  2941.606732   5
# 6   3452  1005.600000  1005.600000   6
# 7   2768  3343.400000  3343.400000   7
# 8   3458  1396.100000  1396.100000   8
# 9   2921   773.300000   773.300000   9

# %%
sns.lineplot(x='Id',y='Actual',data=Results.head(50))
sns.lineplot(x='Id',y='Predicted',data=Results.head(50))
plt.plot()
# Out:
# []

# %%
sns.lineplot(x='Id',y='Actual',data=Results.tail(50))
sns.lineplot(x='Id',y='Predicted',data=Results.tail(50))
plt.plot()
# Out:
# []

# %% [markdown]
# # RidgeRegression

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.grid_search import GridSearchCV


from sklearn.linear_model import Ridge

alpha = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20,30]

ridge = Ridge()

parameters = {'alpha': alpha}

ridge_regressor = GridSearchCV(ridge, parameters)

ridge_regressor.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20, 30]})

# %%
ridge_regressor.best_params_
# Out:
# {'alpha': 1e-15}

# %%
ridge=Ridge(alpha=30)
ridge.fit(x_train,y_train)
y_pred_ridge=ridge.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
Ridge_Error=mean_squared_error(y_pred_ridge,y_test)
Ridge_Error
# Out:
# 2.0457151875851195e-07

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_ridge)
# Out:
# 0.9999999999997388

# %%
Results= pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=y_pred_ridge
#Results['km']=X_test['km']
Results=Results.reset_index()
Results['Id']=Results.index
Results.head(10)
# Out:
#    index       Actual    Predicted  Id
# 0    246  1163.400000  1163.399841   0
# 1   2724   482.300000   482.300392   1
# 2   2033   424.800000   424.800056   2
# 3   2693   390.300000   390.300408   3
# 4    221  1545.500000  1545.499811   4
# 5     30  2941.606732  2941.606693   5
# 6   3452  1005.600000  1005.600116   6
# 7   2768  3343.400000  3343.400082   7
# 8   3458  1396.100000  1396.099924   8
# 9   2921   773.300000   773.300360   9

# %%
sns.lineplot(x='Id',y='Actual',data=Results.head(50))
sns.lineplot(x='Id',y='Predicted',data=Results.head(50))
plt.plot()
# Out:
# []

# %%
sns.lineplot(x='Id',y='Actual',data=Results.tail(50))
sns.lineplot(x='Id',y='Predicted',data=Results.tail(50))
plt.plot()
# Out:
# []

# %% [markdown]
# # ElasticNet Regression

# %%
from sklearn.linear_model import ElasticNet

elastic = ElasticNet()

parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]}

elastic_regressor = GridSearchCV(elastic, parameters)

elastic_regressor.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=ElasticNet(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20]})

# %%
elastic_regressor.best_params_
# Out:
# {'alpha': 1e-15}

# %%
elastic=ElasticNet(alpha=.01)
elastic.fit(x_train,y_train)
y_pred_elastic=elastic.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_elastic)
# Out:
# 0.9999999999741478

# %%
elastic_Error=mean_squared_error(y_pred_elastic,y_test)
elastic_Error
# Out:
# 2.0247640898517207e-05

# %%
Results= pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=y_pred_elastic
#Results['km']=X_test['km']
Results=Results.reset_index()
Results['Id']=Results.index
Results.head(10)
# Out:
#    index       Actual    Predicted  Id
# 0    246  1163.400000  1163.405532   0
# 1   2724   482.300000   482.301411   1
# 2   2033   424.800000   424.802867   2
# 3   2693   390.300000   390.300543   3
# 4    221  1545.500000  1545.497234   4
# 5     30  2941.606732  2941.610653   5
# 6   3452  1005.600000  1005.603652   6
# 7   2768  3343.400000  3343.406365   7
# 8   3458  1396.100000  1396.105345   8
# 9   2921   773.300000   773.303239   9

# %%
sns.lineplot(x='Id',y='Actual',data=Results.head(50))
sns.lineplot(x='Id',y='Predicted',data=Results.head(50))
plt.plot()
# Out:
# []

# %%
sns.lineplot(x='Id',y='Actual',data=Results.tail(50))
sns.lineplot(x='Id',y='Predicted',data=Results.tail(50))
plt.plot()
# Out:
# []

# %% [markdown]
# # RandomForest

# %%
from sklearn.model_selection import GridSearchCV #GridSearchCV is for parameter tuning
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor()
n_estimators=[25,50,75,100,125,150,175,200] #number of decision trees in the forest, default = 100
criterion=['mse'] #criteria for choosing nodes default = 'gini'
max_depth=[3,5,10] #maximum number of nodes in a tree default = None (it will go till all possible nodes)
parameters={'n_estimators': n_estimators,'criterion':criterion,'max_depth':max_depth}  
RFC_reg = GridSearchCV(reg, parameters)
RFC_reg.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse'], 'max_depth': [3, 5, 10],
#                          'n_estimators': [25, 50, 75, 100, 125, 150, 175, 200]})

# %%
RFC_reg.best_params_
# Out:
# {'criterion': 'mse', 'max_depth': 10, 'n_estimators': 100}

# %%
reg=RandomForestRegressor(n_estimators=125,criterion='mse',max_depth=5)

# %%
reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor(criterion='mse', max_depth=5, n_estimators=125)

# %%
y_rfr_pred=reg.predict(x_test)

# %%
y_rfr_pred
# Out:
# array([1154.46970762,  763.07048371,  430.76021206, ...,  837.70914167,
#        2773.70927773,  792.30403432])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_rfr_pred)
# Out:
# 0.9436654232710973

# %%
Results= pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=y_rfr_pred
#Results['km']=X_test['km']
Results=Results.reset_index()
Results['Id']=Results.index
Results.head(10)
# Out:
#    index       Actual    Predicted  Id
# 0    246  1163.400000  1154.469708   0
# 1   2724   482.300000   763.070484   1
# 2   2033   424.800000   430.760212   2
# 3   2693   390.300000   563.917103   3
# 4    221  1545.500000  1203.422929   4
# 5     30  2941.606732  2876.565901   5
# 6   3452  1005.600000   885.346691   6
# 7   2768  3343.400000  3181.972660   7
# 8   3458  1396.100000  1343.555949   8
# 9   2921   773.300000   871.432181   9

# %%
sns.lineplot(x='Id',y='Actual',data=Results.head(50))
sns.lineplot(x='Id',y='Predicted',data=Results.head(50))
plt.plot()
# Out:
# []

# %%
sns.lineplot(x='Id',y='Actual',data=Results.tail(50))
sns.lineplot(x='Id',y='Predicted',data=Results.tail(50))
plt.plot()
# Out:
# []
